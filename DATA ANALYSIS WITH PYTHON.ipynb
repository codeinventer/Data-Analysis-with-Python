# %%
import pandas as pd
d = pd.read_csv("C:\\Users\\Hukam Singh\\Documents\\ML datasets\\data.csv")
print(d)
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2012     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
print(d)
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2012     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
print(d.dtypes)
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
print(d.describe(include='all'))
# Out:
#              Make           Model          Year  Engine Fuel Type  \
# count       11914           11914  11914.000000             11911
# unique         48             915           NaN                10
# top     Chevrolet  Silverado 1500           NaN  regular unleaded
# freq         1123             156           NaN              7172
# mean          NaN             NaN   2010.384338               NaN
# std           NaN             NaN      7.579740               NaN
# min           NaN             NaN   1990.000000               NaN
# 25%           NaN             NaN   2007.000000               NaN
# 50%           NaN             NaN   2015.000000               NaN
# 75%           NaN             NaN   2016.000000               NaN
# max           NaN             NaN   2017.000000               NaN
#
#           Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# count   11845.00000      11884.000000             11914              11914
# ...

# %%
print(d.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
# Make                 11914 non-null object
# Model                11914 non-null object
# Year                 11914 non-null int64
# Engine Fuel Type     11911 non-null object
# Engine HP            11845 non-null float64
# Engine Cylinders     11884 non-null float64
# Transmission Type    11914 non-null object
# Driven_Wheels        11914 non-null object
# Number of Doors      11908 non-null float64
# Market Category      8172 non-null object
# Vehicle Size         11914 non-null object
# Vehicle Style        11914 non-null object
# highway MPG          11914 non-null int64
# city mpg             11914 non-null int64
# Popularity           11914 non-null int64
# MSRP                 11914 non-null int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB
# None

# %%
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2012     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
a = d['Make']
a
b = d[['Make']]
b
# Out:
#           Make
# 0          BMW
# 1          BMW
# 2          BMW
# 3          BMW
# 4          BMW
# 5          BMW
# 6          BMW
# 7          BMW
# 8          BMW
# 9          BMW
# 10         BMW
# 11         BMW
# 12         BMW
# 13         BMW
# 14         BMW
# 15         BMW
# 16         BMW
# 17        Audi
# 18        Audi
# 19        Audi
# 20        Audi
# 21        Audi
# 22        Audi
# 23        Audi
# 24        Audi
# 25        Audi
# 26        Audi
# 27        Audi
# 28        Audi
# 29        Audi
# ...        ...
# 11884      BMW
# 11885      BMW
# 11886      BMW
# 11887      BMW
# 11888      BMW
# 11889      BMW
# 11890      BMW
# 11891      BMW
# 11892      BMW
# 11893      BMW
# 11894      BMW
# 11895      BMW
# 11896      BMW
# 11897      BMW
# 11898      BMW
# 11899      BMW
# 11900      BMW
# 11901      BMW
# 11902      BMW
# 11903      BMW
# 11904      BMW
# 11905      BMW
# 11906    Acura
# 11907    Acura
# 11908    Acura
# 11909    Acura
# ...

# %%
d.iloc[1,2]='NaN'
d.iloc[5,2]='NaN'
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series   NaN     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series   NaN     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
d
d.dropna(subset=["Year"],axis=0,inplace=True)
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series   NaN     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series   NaN     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
d=d[d['Year'].notna()]
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series   NaN     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series   NaN     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
import numpy as np
mea = d["Engine HP"].mean()
print(mea)
d["Year"].replace(np.nan,mea)
d
# Out:
# 249.38607007176023
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series   NaN     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series   NaN     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
d.describe(include='all')
# Out:
#              Make           Model     Year  Engine Fuel Type    Engine HP  \
# count       11914           11914  11914.0             11911  11845.00000
# unique         48             915     29.0                10          NaN
# top     Chevrolet  Silverado 1500   2015.0  regular unleaded          NaN
# freq         1123             156   2170.0              7172          NaN
# mean          NaN             NaN      NaN               NaN    249.38607
# std           NaN             NaN      NaN               NaN    109.19187
# min           NaN             NaN      NaN               NaN     55.00000
# 25%           NaN             NaN      NaN               NaN    170.00000
# 50%           NaN             NaN      NaN               NaN    227.00000
# 75%           NaN             NaN      NaN               NaN    300.00000
# max           NaN             NaN      NaN               NaN   1001.00000
#
#         Engine Cylinders Transmission Type      Driven_Wheels  \
# ...

# %%
d.iloc[1,2]=2011
d.iloc[5,2]=2011
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
d['city mpg'] = 235/d['city mpg']
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
d.rename(columns= {'city mpg':'city L/km'} , inplace = True)
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
d['highway MPG']=235/d['highway MPG']
d.rename(columns={'highway MPG':'highway L/km'})
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
d.rename(columns={'highway MPG':'highway L/km'})
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
d.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG          float64
# city L/km            float64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
d['MSRP'].tail()
# Out:
# 11909    46120
# 11910    56670
# 11911    50620
# 11912    50920
# 11913    28995
# Name: MSRP, dtype: int64

# %%
d[['Engine HP']] = d[['Engine HP']].apply(pd.to_numeric)

# %%
d['Engine HP']
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
# 5        230.0
# 6        300.0
# 7        300.0
# 8        230.0
# 9        230.0
# 10       300.0
# 11       230.0
# 12       300.0
# 13       230.0
# 14       230.0
# 15       320.0
# 16       320.0
# 17       172.0
# 18       172.0
# 19       172.0
# 20       172.0
# 21       172.0
# 22       172.0
# 23       172.0
# 24       172.0
# 25       172.0
# 26       172.0
# 27       172.0
# 28       172.0
# 29       172.0
#          ...
# 11884    225.0
# 11885    184.0
# 11886    225.0
# 11887    225.0
# 11888    184.0
# 11889    225.0
# 11890    330.0
# 11891    330.0
# 11892    330.0
# 11893    330.0
# 11894    240.0
# 11895    300.0
# 11896    335.0
# 11897    240.0
# 11898    300.0
# 11899    335.0
# 11900    300.0
# 11901    240.0
# 11902    335.0
# 11903    394.0
# 11904    394.0
# 11905    394.0
# 11906    300.0
# 11907    300.0
# 11908    300.0
# 11909    300.0
# 11910    300.0
# ...

# %%
d['Year'].std()
d['Year'].mode()
# Out:
# 0    2015
# dtype: int64

# %%
e = d.columns
type(e)
d.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384254    249.38607          5.628829         3.436093
# std        7.579728    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG     city L/km    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean       9.459677     13.071296   1554.911197  4.059474e+04
# std        2.375420      3.502718   1441.855347  6.010910e+04
# min        0.663842      1.715328      2.000000  2.000000e+03
# ...

# %%
### Normalization ###

# %%
### Simple Feature Scaling  ###

# %%
d['MSRP']=d['MSRP']/d['MSRP'].max()
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
d.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384254    249.38607          5.628829         3.436093
# std        7.579728    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG     city L/km    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  11914.000000
# mean       9.459677     13.071296   1554.911197      0.019650
# std        2.375420      3.502718   1441.855347      0.029096
# min        0.663842      1.715328      2.000000      0.000968
# ...

# %%
d['MSRP']=d["MSRP"]*2.065902e+06
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
### min - max method ###

# %%
d['MSRP']=(d["MSRP"]-d["MSRP"].min())/(d["MSRP"].max()-d["MSRP"].min())
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
d.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384254    249.38607          5.628829         3.436093
# std        7.579728    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG     city L/km    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  11914.000000
# mean       9.459677     13.071296   1554.911197      0.018700
# std        2.375420      3.502718   1441.855347      0.029124
# min        0.663842      1.715328      2.000000      0.000000
# ...

# %%
### Z-score method  ###

# %%
d['MSRP']=(d["MSRP"]-d["MSRP"].mean())/d["MSRP"].std()
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
d.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384254    249.38607          5.628829         3.436093
# std        7.579728    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG     city L/km    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean       9.459677     13.071296   1554.911197  2.036640e-15
# std        2.375420      3.502718   1441.855347  1.000000e+00
# min        0.663842      1.715328      2.000000 -6.420781e-01
# ...

# %%
a = d['Number of Doors'].mean()
d['Number of Doors'].replace(np.nan,a)
d.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384254    249.38607          5.628829         3.436093
# std        7.579728    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG     city L/km    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean       9.459677     13.071296   1554.911197  2.036640e-15
# std        2.375420      3.502718   1441.855347  1.000000e+00
# min        0.663842      1.715328      2.000000 -6.420781e-01
# ...

# %%
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
pd.set_option('display.max_columns', None) 
d
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
d.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384254    249.38607          5.628829         3.436093
# std        7.579728    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG     city L/km    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean       9.459677     13.071296   1554.911197  2.036640e-15
# std        2.375420      3.502718   1441.855347  1.000000e+00
# min        0.663842      1.715328      2.000000 -6.420781e-01
# ...

# %%
d.dropna(subset=['Number of Doors'],axis=0,inplace=True)

# %%
d.describe()
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  11908.000000  11844.000000      11878.000000     11908.000000
# mean    2010.381676    249.352161          5.630662         3.436093
# std        7.580725    109.134095          1.776298         0.881315
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    170.000000          4.000000         2.000000
# 50%     2015.000000    227.000000          6.000000         4.000000
# 75%     2016.000000    300.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG     city L/km    Popularity          MSRP
# count  11908.000000  11908.000000  11908.000000  11908.000000
# mean       9.462257     13.075080   1554.877645     -0.000666
# std        2.370961      3.495942   1442.171396      0.999348
# min        0.663842      1.715328      2.000000     -0.642078
# ...

# %%
d.dropna(subset=['Engine Cylinders'],axis=0,inplace=True)

# %%
d.describe()
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  11878.000000  11815.000000      11878.000000     11878.000000
# mean    2010.382219    249.480491          5.630662         3.435174
# std        7.584148    109.203463          1.776298         0.881722
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    170.000000          4.000000         2.000000
# 50%     2015.000000    227.000000          6.000000         4.000000
# 75%     2016.000000    300.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG     city L/km    Popularity          MSRP
# count  11878.000000  11878.000000  11878.000000  11878.000000
# mean       9.466586     13.081457   1557.009766     -0.000166
# std        2.364569      3.484725   1443.270519      1.000533
# min        0.663842      1.715328      2.000000     -0.642078
# ...

# %%
d.dropna(subset=['Engine HP'],axis=0,inplace=True)
d.describe()
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  11815.000000  11815.000000      11815.000000     11815.000000
# mean    2010.359882    249.480491          5.649513         3.432670
# std        7.594346    109.203463          1.751433         0.882853
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    170.000000          4.000000         2.000000
# 50%     2015.000000    227.000000          6.000000         4.000000
# 75%     2016.000000    300.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG     city L/km    Popularity          MSRP
# count  11815.000000  11815.000000  11815.000000  11815.000000
# mean       9.490378     13.118741   1553.407533     -0.000672
# std        2.335681      3.435433   1439.986399      1.002801
# min        0.663842      1.715328      2.000000     -0.642078
# ...

# %%
d. to_csv('C:\\Users\\Hukam Singh\\Documents\\ML datasets\\processed_data.csv')

# %%
z = d
z
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
z.drop(['Market Category','Make'],axis=1)
z
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2011     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
z.drop(z.columns[[0,2,6]],axis=1,inplace=True)
z
# Out:
#             Model                Engine Fuel Type  Engine HP  \
# 0      1 Series M     premium unleaded (required)      335.0
# 1        1 Series     premium unleaded (required)      300.0
# 2        1 Series     premium unleaded (required)      300.0
# 3        1 Series     premium unleaded (required)      230.0
# 4        1 Series     premium unleaded (required)      230.0
# 5        1 Series     premium unleaded (required)      230.0
# 6        1 Series     premium unleaded (required)      300.0
# 7        1 Series     premium unleaded (required)      300.0
# 8        1 Series     premium unleaded (required)      230.0
# 9        1 Series     premium unleaded (required)      230.0
# 10       1 Series     premium unleaded (required)      300.0
# 11       1 Series     premium unleaded (required)      230.0
# 12       1 Series     premium unleaded (required)      300.0
# 13       1 Series     premium unleaded (required)      230.0
# ...

# %%
z.describe()
# Out:
#           Engine HP  Engine Cylinders  Number of Doors   highway MPG  \
# count  11815.000000      11815.000000     11815.000000  11815.000000
# mean     249.480491          5.649513         3.432670      9.490378
# std      109.203463          1.751433         0.882853      2.335681
# min       55.000000          0.000000         2.000000      0.663842
# 25%      170.000000          4.000000         2.000000      7.833333
# 50%      227.000000          6.000000         4.000000      9.038462
# 75%      300.000000          6.000000         4.000000     10.681818
# max     1001.000000         16.000000         4.000000     19.583333
#
#           city L/km    Popularity          MSRP
# count  11815.000000  11815.000000  11815.000000
# mean      13.118741   1553.407533     -0.000672
# std        3.435433   1439.986399      1.002801
# min        1.715328      2.000000     -0.642078
# 25%       10.681818    549.000000     -0.326153
# 50%       13.055556   1385.000000     -0.176924
# ...

# %%
z
# Out:
#             Model                Engine Fuel Type  Engine HP  \
# 0      1 Series M     premium unleaded (required)      335.0
# 1        1 Series     premium unleaded (required)      300.0
# 2        1 Series     premium unleaded (required)      300.0
# 3        1 Series     premium unleaded (required)      230.0
# 4        1 Series     premium unleaded (required)      230.0
# 5        1 Series     premium unleaded (required)      230.0
# 6        1 Series     premium unleaded (required)      300.0
# 7        1 Series     premium unleaded (required)      300.0
# 8        1 Series     premium unleaded (required)      230.0
# 9        1 Series     premium unleaded (required)      230.0
# 10       1 Series     premium unleaded (required)      300.0
# 11       1 Series     premium unleaded (required)      230.0
# 12       1 Series     premium unleaded (required)      300.0
# 13       1 Series     premium unleaded (required)      230.0
# ...

# %%
z.drop(["Transmission Type"],axis=1)
z
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-bc0e5c93a191> in <module>()
# ----> 1 z.drop(["Transmission Type"],axis=1)
#       2 z
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
z

# %%
z=z.drop(['Market Category'],axis=1)

# %%
z

# %%
z

# %%
z.drop(['Transmission Type'],axis=1,inplace=True)
z

# %%
del z['Popularity']

# %%
z

# %%
z

# %%
d

# %%
d.describe()

# %%
d = pd.read_csv('C:\\Users\\Hukam Singh\\Documents\\ML datasets\\processed_data.csv')
d

# %%
d.describe(include='all')

# %%
d['Market Category'].replace(np.nan,'Crossover',inplace=True)

# %%
d.describe(include='all')

# %%
d['Engine Fuel Type']=d['Engine Fuel Type'].replace(np.nan,'regular unleaded')

# %%
d.describe(include='all')

# %%
d. to_csv('C:\\Users\\Hukam Singh\\Documents\\ML datasets\\completely_processed_data.csv')

# %%
d.describe(include='all')

# %%
a=max(d['MSRP'])
a

# %%
b=d["MSRP"].max()

# %%
bins = np.linspace(min(d["Number of Doors"]),max(d["Number of Doors"]),4)
print(bins)
group_names = ['Low','Medium','High']
d['Number of Doors'] = pd.cut(d['Number of Doors'],bins,labels=group_names,include_lowest=True)

# %%
bins = np.linspace(min(d["Engine Cylinders"]),max(d["Engine Cylinders"]),4)
print(bins)
group_names = ['Low','Medium','High']
d['Engine Cylinders'] = pd.cut(d['Engine Cylinders'],bins,labels=group_names,include_lowest=True)

# %%
d

# %%
m=pd.get_dummies(d['Engine Fuel Type'])
m

# %%
d.describe(include='all')

# %%
a=d['Driven_Wheels'].value_counts()
#print(a)
a=a.rename(columns={'Driven_Wheels':'Value_Counts'}, inplace = True)
#print(a)
a.index.name='Driven_Wheels'
print(a)

# %%
import seaborn as sns
sns.boxplot(x="Driven_Wheels",y="MSRP",data=d)

# %%
import matplotlib.pyplot as plt
x=d["Engine HP"]
y = d["MSRP"]
plt.scatter(x,y)
plt.title("Scatter plot of engine-hp vs msrp")
plt.xlabel("Engine HP")
plt.ylabel("MSRP")

# %%
d

# %%
f = d[['Vehicle Size','Number of Doors',"Popularity"]]
g = f.groupby(['Vehicle Size',"Number of Doors"],as_index=False).mean()
g

# %%
g_pivot=g.pivot(index='Number of Doors',columns = 'Vehicle Size')
g_pivot

# %%
plt.pcolor(g_pivot,cmap='RdBu')
plt.colorbar()
plt.show()

# %%
#d['MSRP']=d["MSRP"]*5

d.describe()
#sns.regplot(d['Engine HP'],d['M'])

# %%
sns.regplot(x='Engine HP',y='MSRP',data=d)
plt.ylim(0,)

# %%
sns.regplot(x='highway MPG',y='MSRP',data=d)
plt.ylim(0,)

# %%
sns.regplot(x='city L/km',y='MSRP',data=d)
plt.ylim(0,)

# %%
import scipy.stats as e
pea_corr_coef,p_value = e.pearsonr(d['Popularity'],d['MSRP'])
print(pea_corr_coef,p_value)
# Out:
# -0.04853554627858689 1.3045029029176304e-07

# %%
d
# Out:
#             Model                Engine Fuel Type  Engine HP  \
# 0      1 Series M     premium unleaded (required)      335.0
# 1        1 Series     premium unleaded (required)      300.0
# 2        1 Series     premium unleaded (required)      300.0
# 3        1 Series     premium unleaded (required)      230.0
# 4        1 Series     premium unleaded (required)      230.0
# 5        1 Series     premium unleaded (required)      230.0
# 6        1 Series     premium unleaded (required)      300.0
# 7        1 Series     premium unleaded (required)      300.0
# 8        1 Series     premium unleaded (required)      230.0
# 9        1 Series     premium unleaded (required)      230.0
# 10       1 Series     premium unleaded (required)      300.0
# 11       1 Series     premium unleaded (required)      230.0
# 12       1 Series     premium unleaded (required)      300.0
# 13       1 Series     premium unleaded (required)      230.0
# ...

# %%
from scipy import stats
df = d[['Vehicle Style','MSRP']]
g1 = df.groupby(['MSRP'])
anova_results = stats.f_oneway(g1.get_group('Compact')['MSRP'],g1.get_group('Midsize')['MSRP'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-adf8be5b853c> in <module>()
#       2 df = d[['Vehicle Style','MSRP']]
#       3 g1 = df.groupby(['MSRP'])
# ----> 4 anova_results = stats.f_oneway(g1.get_group('Compact')['MSRP'],g1.get_group('Midsize')['MSRP'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     875         inds = self._get_index(name)
#     876         if not len(inds):
# --> 877             raise KeyError(name)
#     878
#     879         return obj._take(inds, axis=self.axis)
#
# KeyError: 'Compact'
